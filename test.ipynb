# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(0, datetime.datetime(1970, 1, 1, 0, 25, 41, 721978), 42, 'paid', 'Supermassive Black Hole (Twilight Soundtrack Version)', 'Muse', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (1, datetime.datetime(1970, 1, 1, 0, 25, 41, 722187), 42, 'paid', 'Lighten Up', 'Beastie Boys', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (2, datetime.datetime(1970, 1, 1, 0, 25, 41, 722348), 42, 'paid', 'Pienso En Ti', 'Shakira', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (3, datetime.datetime(1970, 1, 1, 0, 25, 41, 722493), 42, 'paid', 'Amor Prohibido', 'Selena', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (4, datetime.datetime(1970, 1, 1, 0, 25, 41, 722665), 42, 'paid', "Day 'N' Nite", 'Kid Cudi Vs Crookers', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('55', 'Martin', 'Johnson', 'M', 'free'),
#  ('95', 'Sara', 'Johnson', 'F', 'paid'),
#  ('6', 'Cecilia', 'Owens', 'F', 'free'),
#  ('24', 'Layla', 'Griffin', 'F', 'paid'),
#  ('13', 'Ava', 'Robinson', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, Decimal('305.16')),
#  ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 'ARJIE2Y1187B994AB7', 0, Decimal('152.92')),
#  ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 'ARPFHN61187FB575F6', 0, Decimal('279.98')),
#  ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, Decimal('75.68')),
#  ('SONSKXP12A8C13A2C9', 'Native Soul', 'AR0IAWL1187B9A96D0', 2003, Decimal('197.20'))]

# %%
# %sql SELECT * FROM artists LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', Decimal('40.79'), Decimal('-73.97')),
#  ('ARJIE2Y1187B994AB7', 'Line Renaud', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', Decimal('41.88'), Decimal('-87.63')),
#  ('AR558FS1187FB45658', '40 Grit', '', Decimal('NaN'), Decimal('NaN')),
#  ('AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', Decimal('8.42'), Decimal('-80.11')),
#  ('AR051KA1187B98B2FF', 'Wilks', '', Decimal('NaN'), Decimal('NaN')),
#  ('AR8IEZO1187B99055E', 'Marc Shaiman', '', Decimal('NaN'), Decimal('NaN')),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', Decimal('-13.44'), Decimal('-42.00')),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARULZCI1241B9C8611', 'Luna Orbit Project', '', Decimal('NaN'), Decimal('NaN'))]

# %%
# %sql SELECT * FROM time LIMIT 100;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 100 rows affected.
# [(datetime.datetime(1970, 1, 1, 0, 25, 41, 721978), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 722187), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 722348), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 722493), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 722665), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 722827), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 723006), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 723217), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 723413), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 723625), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 723841), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 724134), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 724356), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 724632), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 724857), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 725065), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 725312), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 725606), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 725923), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 726126), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 726505), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 726741), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 727013), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 727280), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 727554), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 727724), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 727985), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 728306), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 728518), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 728709), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 728930), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 729360), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 729637), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 730102), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 730129), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 737557), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 743963), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 744263), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 751690), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 763876), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 764057), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 764254), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 764376), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 768835), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 768950), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 771197), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 771530), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 771756), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 771762), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 772073), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 772226), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 772489), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 772778), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 773272), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 773368), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 773400), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 773588), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 773783), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 773833), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 773977), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 774040), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 774192), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 774359), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 774438), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 774603), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 774724), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 775034), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 775054), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 775230), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 775545), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 775620), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 775844), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 776080), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 776603), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 776855), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 776954), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777119), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777154), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777160), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777356), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777368), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777443), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777489), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777560), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777586), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 777783), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778004), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778223), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778361), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778427), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778455), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778656), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778723), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 778837), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 779047), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 779067), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 779330), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 779388), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 779403), 0, 'Thursday', '1', '1', 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 779510), 0, 'Thursday', '1', '1', 1970, '3')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
